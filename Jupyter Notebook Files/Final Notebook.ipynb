# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
# File to Load 
clusters_data = "Map geographical clusters.csv"

# Read aquacultral farm data File and store into Pandas data frame
df = pd.read_csv("Map geographical clusters.csv")
df.head()
# Out:
#    cluster  Area (ha)  Latitude_p  Longitude_p  Description
# 0        1        2.4        28.0        -15.4  Sample Data
# 1        2        0.5        28.5        -16.2  Sample Data
# 2        3        2.5        28.7        -18.0  Sample Data
# 3        4        2.2        28.0        -16.7  Sample Data
# 4        5       12.6        35.8         14.6  Sample Data

# %%
df['Area_log'] = np.log(df['Area (ha)'])
df
# Out:
# C:\Users\Amina Hajisaid\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      cluster  Area (ha)  Latitude_p  Longitude_p  Description  Area_log
# 0          1        2.4        28.0        -15.4  Sample Data  0.875469
# 1          2        0.5        28.5        -16.2  Sample Data -0.693147
# 2          3        2.5        28.7        -18.0  Sample Data  0.916291
# 3          4        2.2        28.0        -16.7  Sample Data  0.788457
# 4          5       12.6        35.8         14.6  Sample Data  2.533697
# ..       ...        ...         ...          ...          ...       ...
# 212      215        2.0        38.7         23.1  Sample Data  0.693147
# 213      216       13.9        38.2         26.6  Sample Data  2.631889
# 214      217        0.6        38.7         23.4  Sample Data -0.510826
# ...

# %%
nitrogen = df.to_html()
print(nitrogen)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cluster</th>
#       <th>Area (ha)</th>
#       <th>Latitude_p</th>
#       <th>Longitude_p</th>
#       <th>Description</th>
#       <th>Area_log</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2.4</td>
#       <td>28.0</td>
#       <td>-15.4</td>
#       <td>Sample Data</td>
#       <td>0.875469</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>0.5</td>
#       <td>28.5</td>
#       <td>-16.2</td>
#       <td>Sample Data</td>
#       <td>-0.693147</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>2.5</td>
#       <td>28.7</td>
#       <td>-18.0</td>
#       <td>Sample Data</td>
#       <td>0.916291</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>2.2</td>
#       <td>28.0</td>
#       <td>-16.7</td>
#       <td>Sample Data</td>
# ...

# %%
locations = []

for index, rows in df.iterrows():
    locations.append((rows.Latitude_p, rows.Longitude_p))
    
locations
# Out:
# [(28.0, -15.4),
#  (28.5, -16.2),
#  (28.7, -18.0),
#  (28.0, -16.7),
#  (35.8, 14.6),
#  (35.5, 24.1),
#  (37.1, 13.9),
#  (36.7, 15.1),
#  (35.3, 26.3),
#  (36.0, 14.4),
#  (34.6, 33.0),
#  (36.7, -4.4),
#  (34.7, 33.3),
#  (36.8, -2.0),
#  (36.7, -2.9),
#  (36.8, -2.5),
#  (36.5, -4.9),
#  (36.6, -4.6),
#  (36.7, -3.6),
#  (37.0, -1.9),
#  (35.0, 33.9),
#  (37.4, -1.5),
#  (38.1, 12.9),
#  (38.1, 13.0),
#  (37.6, -0.9),
#  (37.5, -1.4),
#  (37.5, -1.2),
#  (37.3, 23.3),
#  (36.3, 27.8),
#  (37.2, -1.8),
#  (37.1, 23.0),
#  (36.6, 26.4),
#  (36.8, 21.7),
#  (36.2, -5.4),
#  (36.2, -5.9),
#  (35.3, 34.0),
#  (36.7, 28.1),
#  (38.1, -0.6),
#  (36.9, 28.0),
#  (37.8, -0.7),
#  (37.0, 27.0),
#  (36.9, 27.2),
#  (37.6, 23.4),
#  (37.0, 27.0),
#  (36.2, 29.6),
#  (37.1, 24.5),
#  (37.3, 22.8),
#  (37.5, 23.0),
#  (38.2, 15.0),
#  (36.6, 27.8),
#  (38.2, 15.3),
#  (38.6, 0.0),
#  (37.6, 26.6),
#  (37.9, 24.7),
#  (38.8, 1.4),
#  (38.6, 20.9),
#  (36.4, 34.1),
#  (36.3, 33.9),
# ...

# %%
# import the library
import folium

# Make an empty map

new_m = folium.Map(location=[35,14], tiles="OpenStreetMap", zoom_start=4.3, control_scale = True)

# Show the map
new_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for i in range(0,len(df)):
   folium.CircleMarker(
      location=[df.iloc[i]['Latitude_p'], df.iloc[i]['Longitude_p']],
      popup=[df.iloc[i]['cluster'], df.iloc[i]['Description']],
      radius=float(df.iloc[i]['Area_log']),
      color='#AA4A44',
      fill=True,
      fill_color='#AA4A44'
   ).add_to(new_m)
new_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
